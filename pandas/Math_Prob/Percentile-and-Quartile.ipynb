# %% [markdown]
# ># Percentile
# * Value below which a certain % of data falls.
# $$
# P(\text{k}) =
# {\text{X}}
# \frac{\text{k}}
# {\text{100}}
# {\text{(n+1)}}
# $$
#
#
# **Where**
#
# k = percentile number (1–99)
#
# n = number of data points
#
# 𝑥 = i-th value in sorted data

# %% [markdown]
# <br><br>

# %% [markdown]
# ># Quantiles
#
# **Divide data into equal-sized segments.**
#
# Formula (quantile for probability)
# $$
# Q^(\text{p}) =
# {\text{X}}
# {\text{(n+1)}}
# $$
#
# **Where:**
#
# * Q(p) = quantile
#
# * p∈[0,1] (example: 0.25 → 25th percentile)
#
# * n = number of observations
#
#
#
#
# ---------------------------------------------------------------------------------------------------------------------
# Q1 (25th percentile) :
# $$
# Q^(\text{p}) =
# {\text{X}}_
# {\text{0.25}}
# {\text{(n+1)}}
# $$
#
#
# Q2 (50th percentile / Median):
# $$
# Q^(\text{p}) =
# {\text{X}}_
# {\text{0.50}}
# {\text{(n+1)}}
# $$
#
#
#
# Q3 (75th percentile):
# $$
# Q^(\text{p}) =
# {\text{X}}_
# {\text{0.75}}
# {\text{(n+1)}}
# $$
